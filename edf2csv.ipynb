# %%
from pyedflib import highlevel
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
edf_paths = glob('./edf_files/*.edf')

# %%
signals, signal_headers, header = highlevel.read_edf(edf_paths[0])

# %%
ecg = signals[3]
plt.plot(ecg)
